# %% [markdown]
# # Homework 4 - Functions II

# %%
import pandas as pd
import numpy as np

# %% [markdown]
# ## 1.Import the data as a pd.DataFrame object. Use one or more functions from the pandas library to split the data into three unique datasets.
